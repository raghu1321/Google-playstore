# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Load the data file using pandas.

# %%
data=pd.read_csv("R:/Nptel/Com Class data/Pythone/simpli dataset/1569582940_googleplaystore (1)/googleplaystore.csv")

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# 2. Check for null values in the data. Get the number of null values for each column.

# %%
data.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10,000+  Free     0       Everyone
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# 3. Drop records with nulls in any of the columns.

# %%
data.dropna()
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data_g=data.dropna()

# %%
data_g
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# 4.Variables seem to have incorrect type and inconsistent formatting. You need to fix them:
#
# 1.Size column has sizes in Kb as well as Mb. To analyze, you’ll need to convert these to numeric.
#
# 4.2.2 Reviews is a numeric field that is loaded as a string field. Convert it to numeric (int/float).

# %%
data_g.Size
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10834                  2.6M
# 10836                   53M
# 10837                  3.6M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 9360, dtype: object

# %%
a=data_g.Size.str.replace("M"," ")

# %%
a
# Out:
# 0                       19
# 1                       14
# 2                      8.7
# 3                       25
# 4                      2.8
#                 ...
# 10834                  2.6
# 10836                   53
# 10837                  3.6
# 10839    Varies with device
# 10840                   19
# Name: Size, Length: 9360, dtype: object

# %%
d=pd.to_numeric(a, errors='coerce') # convert these to numeric

# %%
d
# Out:
# 0        19.0
# 1        14.0
# 2         8.7
# 3        25.0
# 4         2.8
#          ...
# 10834     2.6
# 10836    53.0
# 10837     3.6
# 10839     NaN
# 10840    19.0
# Name: Size, Length: 9360, dtype: float64

# %%
d*1000        # converted into MB to Kb
# Out:
# 0        19000.0
# 1        14000.0
# 2         8700.0
# 3        25000.0
# 4         2800.0
#           ...
# 10834     2600.0
# 10836    53000.0
# 10837     3600.0
# 10839        NaN
# 10840    19000.0
# Name: Size, Length: 9360, dtype: float64

# %%
data_g.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data_g ["Reviews"].astype(float)
# Out:
# 0           159.0
# 1           967.0
# 2         87510.0
# 3        215644.0
# 4           967.0
#            ...
# 10834         7.0
# 10836        38.0
# 10837         4.0
# 10839       114.0
# 10840    398307.0
# Name: Reviews, Length: 9360, dtype: float64

# %%
data_g ["Reviews"].astype(int)
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10834         7
# 10836        38
# 10837         4
# 10839       114
# 10840    398307
# Name: Reviews, Length: 9360, dtype: int32

# %% [markdown]
# 3.Installs field is currently stored as string and has values like 1,000,000+.
#
# 1.Treat 1,000,000+ as 1,000,000
#
# 2.remove ‘+’, ‘,’ from the field, convert it to integer

# %%
data_g.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10,000+  Free     0       Everyone
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
l=data_g["Installs"].str.replace(",","").str.replace("+","")
# Out:
# C:\Users\RAGHU\AppData\Local\Temp/ipykernel_1572/72281762.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   l=data_g["Installs"].str.replace(",","").str.replace("+","")

# %%
l
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10834         500
# 10836        5000
# 10837         100
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 9360, dtype: object

# %%
l.astype(int)
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10834         500
# 10836        5000
# 10837         100
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 9360, dtype: int32

# %% [markdown]
# 4. Price field is a string and has $ symbol. Remove ‘$’ sign, and convert it to numeric.

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
data["Price"].str.replace("$","")
# Out:
# C:\Users\RAGHU\AppData\Local\Temp/ipykernel_1572/3413989070.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data["Price"].str.replace("$","")
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10836    0
# 10837    0
# 10838    0
# 10839    0
# 10840    0
# Name: Price, Length: 10841, dtype: object

# %% [markdown]
# 5.Sanity checks:
#
# 1. Average rating should be between 1 and 5 as only these values are allowed on the play store. Drop the rows that have a value outside this range.

# %%
data[(data["Rating"]>1) & (data["Rating"]<5)]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# 5.Sanity checks:
#
# 2.Reviews should not be more than installs as only those who installed can review the app. If there are any such records, drop them.

# %%
data[(data["Reviews"]) < (data["Installs"])]
# Out:
#                                                 App             Category  \
# 3                             Sketch - Draw & Paint       ART_AND_DESIGN
# 5                        Paper flowers instructions       ART_AND_DESIGN
# 6           Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 16     Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 18                    FlipaClip - Cartoon animation       ART_AND_DESIGN
# ...                                             ...                  ...
# 10823                                  List iptv FR        VIDEO_PLAYERS
# 10827                            Fr Agnel Ambarnath               FAMILY
# 10831                      payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10835                                      FR Forms             BUSINESS
# 10836                              Sya9a Maroc - FR               FAMILY
#
#        Rating Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
a=[i*0 if google_df.Type=='Free' else i*1 for i in google_df.Price]

# %%
(data["Type"]=="Free")
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 10836    True
# 10837    True
# 10838    True
# 10839    True
# 10840    True
# Name: Type, Length: 10841, dtype: bool

# %%
(data["Price"]>="0")
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 10836    True
# 10837    True
# 10838    True
# 10839    True
# 10840    True
# Name: Price, Length: 10841, dtype: bool

# %%
data[(data["Type"]=="Free") & (data["Price"]<"0")]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
J=data["Price"].str.replace("$","")
J
# Out:
# C:\Users\RAGHU\AppData\Local\Temp/ipykernel_1572/86513056.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   J=data["Price"].str.replace("$","")
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10836    0
# 10837    0
# 10838    0
# 10839    0
# 10840    0
# Name: Price, Length: 10841, dtype: object

# %%
J
data.Price1=data[data['Price'] == 0] # price should not be zero
data.Price1.Price
sns.boxplot(data.Price1,J)
# Out:
# C:\Users\RAGHU\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1572/2737714611.py in <module>
#       2 data.Price1=data[data['Price'] == 0] # price should not be zero
#       3 data.Price1.Price
# ----> 4 sns.boxplot(data.Price1,J)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
#5 Histogram for Rating,,How are the ratings distributed? Is it more toward higher ratings?
plt.hist(data.Rating)#in this way we plot histogram
plt.title('HIST PLOT OF RATING')#for giving the title of that plot
plt.show()#we can say that higher rating app is 4.5 star,maximum is 4.5 star app

# %%
#5Histogram for Size,,Note down your observations for the plots made above. Which of these seem to have outliers?
plt.hist(data.Size)
plt.title('HIST PLOT OF SIZE')#for giving the title of that plot
plt.show()#there are otliers

# %%
#6.1 Outlier treatment: Price: From the box plot, it seems like there are some apps with very high price. A price of $200 for an application on the Play Store is very high and suspicious!
#Check out the records with very high price
#Is 200 indeed a high price?
data.Price.describe()#maximum is 400 so we need to drop this value
data[data['Price']<"200"]#remove the records more than 200
data=data[data['Price']<"200"]
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#6.2Reviews: Very few apps have very high number of reviews. These are all star apps that don’t help with the analysis and, in fact, will skew it. Drop records having more than 2 million reviews.
data.Reviews
data[data['Reviews']<"2000000"]#drop the values which is greater than 2million
data=data[data['Reviews']<"2000000"]
data.head()
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 5                      Paper flowers instructions  ART_AND_DESIGN     4.4
# 6         Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 8                            Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                   Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10,000+  Free     0       Everyone
# 5     167  5.6M     50,000+  Free     0       Everyone
# 6     178   19M     50,000+  Free     0       Everyone
# 8   13791   33M  1,000,000+  Free     0       Everyone
# 9     121  3.1M     10,000+  Free     0       Everyone
#
#                     Genres        Last Updated Current Ver   Android Ver
# 0             Art & Design     January 7, 2018       1.0.0  4.0.3 and up
# ...

# %%
#6.3Installs:  There seems to be some outliers in this field too. Apps having very high number of installs should be dropped from the analysis.
#Find out the different percentiles – 10, 25, 50, 70, 90, 95, 99
#Decide a threshold as cutoff for outlier and drop records having values more than that
data.Installs.quantile(0.90)#maximum value is there so this the threshold
max_threshold=data.Installs.quantile(0.90)
data[data["Installs"]<"max_threshold"]
data=data[data["Installs"]<"max_threshold"]
data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1572/3473737567.py in <module>
#       2 #Find out the different percentiles – 10, 25, 50, 70, 90, 95, 99
#       3 #Decide a threshold as cutoff for outlier and drop records having values more than that
# ----> 4 data.Installs.quantile(0.90)#maximum value is there so this the threshold
#       5 max_threshold=data.Installs.quantile(0.90)
#       6 data[data["Installs"]<"max_threshold"]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in quantile(self, q, interpolation)
#    2446         df = self.to_frame()
#    2447
# -> 2448         result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2449         if result.ndim == 2:
#    2450             result = result.iloc[:, 0]
#
# ...

# %%
#7.1 Make scatter plot/joinplot for Rating vs. Price
#What pattern do you observe? Does rating increase with price?
plt.scatter([data.Rating],[data.Price])
plt.xlabel("Rating")
plt.ylabel("Price")
plt.show()    #rating does not increase with price,there is some specific rating  which is greater
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1572/2369485952.py in <module>
#       1 #7.1 Make scatter plot/joinplot for Rating vs. Price
#       2 #What pattern do you observe? Does rating increase with price?
# ----> 3 plt.scatter([data.Rating],[data.Price])
#       4 plt.xlabel("Rating")
#       5 plt.ylabel("Price")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3066         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    3067         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 3068     __ret = gca().scatter(
#    3069         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3070         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ...
